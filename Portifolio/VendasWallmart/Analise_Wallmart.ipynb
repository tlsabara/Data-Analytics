# %%
# Meus imports

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Funções
def my_pair_grid_simple(df) -> object:
    grd = sns.PairGrid(data=df)
    grd.map_upper(sns.kdeplot)
    grd.map_diag(sns.scatterplot)
    return grd

# %%
# Parametros

file_stores = r'.\datasets\stores.csv'
file_features = r'.\datasets\features.csv'
file_sales = r'.\datasets\sales.csv'

df_features = pd.read_csv(file_features)
df_stores = pd.read_csv(file_stores)
df_sales = pd.read_csv(file_sales)

bkp_df_features = df_features
bkp_df_stores = df_stores
bkp_df_sales = df_sales

# %%
df_features.head(10)
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
# 5      1  2010-03-12        57.79       2.667        NaN        NaN
# 6      1  2010-03-19        54.58       2.720        NaN        NaN
# 7      1  2010-03-26        51.45       2.732        NaN        NaN
# 8      1  2010-04-02        62.27       2.719        NaN        NaN
# 9      1  2010-04-09        65.86       2.770        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# ...

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
df_stores.head(10)
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875
# 5      6    A  202505
# 6      7    B   70713
# 7      8    A  155078
# 8      9    B  125833
# 9     10    B  126512

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
df_sales.head(10)
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False
# 5      1     1  2010-03-12      21043.39      False
# 6      1     1  2010-03-19      22136.64      False
# 7      1     1  2010-03-26      26229.21      False
# 8      1     1  2010-04-02      57258.43      False
# 9      1     1  2010-04-09      42960.91      False

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
try:
    del(grd_features)
except Exception as e:
    print(e)
grd_features = sns.PairGrid(data=df_features.drop('IsHoliday', axis=1))
grd_features.map_diag(plt.hist)
grd_features.map_lower(plt.scatter)
grd_features.map_upper(plt.scatter, alpha=0.2)
grd_features.map_upper(sns.kdeplot)

# %% [markdown]
# # Analise 1
#
#   - Utilizando o Pairgrid para customizar.(Montei a função my_pair_grid_simple por necessidade de reuso)
#   - Meu note ta demorando pra processar.
#   -
