# %%
import seaborn as sns
# %matplotlib inline

# %%
df = sns.load_dataset('flights')

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
sns.lmplot(data=df, x='passengers', y='year')

# %% [markdown]
# existe uma relação entre passageiros e os anos onde cada quanto maiot o ano, maior foi o numero de passageiros.

# %%
sns.lmplot(data=df, x='passengers', y='year', row='month', )
