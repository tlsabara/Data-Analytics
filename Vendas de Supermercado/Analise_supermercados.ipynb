# %% [markdown]
# # Analise de dados de Supermercados

# %% [markdown]
# ### Import de libs

# %%
import pandas as pd
import os
from pathlib import Path
import seaborn as sns
import matplotlib.pylab as plt
plt.style.use('ggplot')

# %matplotlib inline

# %% [markdown]
# ### Configurações basicas

# %%
ROOT_DIR = Path(os.path.abspath(os.path.curdir))

# %%
src_file = ROOT_DIR / "source/supermarket_sales - Sheet1.csv"

# %% [markdown]
# ### Iniciando Analise

# %% [markdown]
# Carregando DF e Reconhecendo dados

# %%
df = pd.read_csv(src_file)

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 557  283-26-5248      C  Naypyitaw        Member  Female
# 348  531-80-1784      A     Yangon        Normal    Male
# 550  747-58-7183      B   Mandalay        Normal    Male
# 862  152-03-4217      B   Mandalay        Normal  Female
# 884  548-48-3156      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 557      Food and beverages       98.52        10  49.2600  1034.4600
# 348  Electronic accessories       26.02         7   9.1070   191.2470
# 550     Fashion accessories       57.27         3   8.5905   180.4005
# 862      Home and lifestyle       11.28         9   5.0760   106.5960
# 884      Food and beverages       83.34         2   8.3340   175.0140
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 557  1/30/2019  20:23      Ewallet  985.20                 4.761905
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.isna().mean()
# Out:
# Invoice ID                 0.0
# Branch                     0.0
# City                       0.0
# Customer type              0.0
# Gender                     0.0
# Product line               0.0
# Unit price                 0.0
# Quantity                   0.0
# Tax 5%                     0.0
# Total                      0.0
# Date                       0.0
# Time                       0.0
# Payment                    0.0
# cogs                       0.0
# gross margin percentage    0.0
# gross income               0.0
# Rating                     0.0
# dtype: float64

# %% [markdown]
# #### Resumo de reconhecimento
#
# Sem dados ausentes.
# Apenas as colunas de Date e Time precisam ser corrigidas

# %%
sns.pairplot(
    data=df,
)

# %%
sns.pairplot(
    data=df,
    hue='Branch'
)

# %%
df.groupby('Branch')['Invoice ID'].count()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: Invoice ID, dtype: int64

# %%
sns.relplot(
    data=df,
    x='Total',
    y='Rating',
    hue='Branch',
    col='Gender',
    size='Quantity'
)

# %%
sns.displot(
    data=df,
    x='Total',
    hue='Gender'
)
